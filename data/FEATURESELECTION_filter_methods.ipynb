# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
os.chdir("../data")

# %%
boston_data = pd.read_csv('boston-house-prices\housing.csv')

# %%
boston_data
# Out:
#      0.00632  18.00  2.310    0  0.5380  6.5750  65.20  4.0900    1  296.0  \
# 0    0.02731    0.0   7.07  0.0   0.469  6.4210  78.90  4.9671  2.0  242.0
# 1    0.02729    0.0   7.07  0.0   0.469  7.1850  61.10  4.9671  2.0  242.0
# 2    0.03237    0.0   2.18  0.0   0.458  6.9980  45.80  6.0622  3.0  222.0
# 3    0.06905    0.0   2.18  0.0   0.458  7.1470  54.20  6.0622  3.0  222.0
# 4    0.02985    0.0   2.18  0.0   0.458  6.4300  58.70  6.0622  3.0  222.0
# ..       ...    ...    ...  ...     ...     ...    ...     ...  ...    ...
# 475  0.06263    0.0  11.93  0.0   0.573  6.5930  69.10  2.4786  1.0  273.0
# 476  0.04527    0.0  11.93  0.0   0.573  6.1200  76.70  2.2875  1.0  273.0
# 477  0.06076    0.0  11.93  0.0   0.573  6.9760  91.00  2.1675  1.0  273.0
# 478  0.10959    0.0  11.93  0.0   0.573  6.7940  89.30  2.3889  1.0  273.0
# 479  0.04741    0.0  11.93  0.0   0.573  6.0300  80.80  2.5050  1.0  273.0
#
#      15.30396.90  4.98  24.00
# 0    17.80396.90  9.14   21.6
# ...

# %%
boston_data.drop(columns=['15.30396.90'], inplace=True)

# %%
boston_data.columns = ['CrimeRate', 'ZoneRatio','IndusRatio', 'CharlesRvr','NO2','Roomsperhouse','oldhomeratio','distfromcenter','roadaccessindex','propertytax','pupilteacherratio', 'mediahouseval']

# %%
boston_data.head()
# Out:
#   CrimeRate  ZoneRatio  IndusRatio  CharlesRvr    NO2 Roomsperhouse  \
# 0   0.02731        0.0        7.07         0.0  0.469        6.4210
# 1   0.02729        0.0        7.07         0.0  0.469        7.1850
# 2   0.03237        0.0        2.18         0.0  0.458        6.9980
# 3   0.06905        0.0        2.18         0.0  0.458        7.1470
# 4   0.02985        0.0        2.18         0.0  0.458        6.4300
#
#   oldhomeratio  distfromcenter  roadaccessindex propertytax  \
# 0        78.90          4.9671              2.0       242.0
# 1        61.10          4.9671              2.0       242.0
# 2        45.80          6.0622              3.0       222.0
# 3        54.20          6.0622              3.0       222.0
# 4        58.70          6.0622              3.0       222.0
#
#    pupilteacherratio  mediahouseval
# 0               9.14           21.6
# 1               4.03           34.7
# 2               2.94           33.4
# 3               5.33           36.2
# ...

# %%
boston_data.corr()
# Out:
#                    ZoneRatio  IndusRatio  CharlesRvr       NO2  \
# ZoneRatio           1.000000   -0.521688   -0.046115 -0.208302
# IndusRatio         -0.521688    1.000000    0.063813  0.211143
# CharlesRvr         -0.046115    0.063813    1.000000  0.089088
# NO2                -0.208302    0.211143    0.089088  1.000000
# distfromcenter      0.096619    0.025453   -0.110530  0.002928
# roadaccessindex    -0.102605    0.284547   -0.049882  0.177007
# pupilteacherratio  -0.311695    0.483156   -0.056709  0.293823
# mediahouseval       0.343519   -0.430083    0.186313 -0.127565
#
#                    distfromcenter  roadaccessindex  pupilteacherratio  \
# ZoneRatio                0.096619        -0.102605          -0.311695
# IndusRatio               0.025453         0.284547           0.483156
# CharlesRvr              -0.110530        -0.049882          -0.056709
# NO2                      0.002928         0.177007           0.293823
# ...

# %%
boston_data.describe()
# Out:
#         ZoneRatio  IndusRatio  CharlesRvr         NO2  distfromcenter  \
# count  480.000000  480.000000  480.000000  480.000000      480.000000
# mean    11.736083   10.803458    0.071690    0.561489        5.227678
# std     23.458471    6.845757    0.257262    0.307780        5.120003
# min      0.000000    0.000000    0.000000    0.385000        1.129600
# 25%      0.000000    5.130000    0.000000    0.448000        2.428825
# 50%      0.000000    8.560000    0.000000    0.524000        3.897300
# 75%     20.000000   18.100000    0.000000    0.624000        5.720900
# max     95.000000   27.740000    1.000000    6.816000       24.000000
#
#        roadaccessindex  pupilteacherratio  mediahouseval
# count       480.000000         480.000000     480.000000
# mean         61.947917          12.346729      23.465525
# std         168.291697           7.147232       8.515273
# min           1.000000           1.730000       6.300000
# ...

# %%
boston_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CrimeRate          480 non-null    object
#  1   ZoneRatio          480 non-null    float64
#  2   IndusRatio         480 non-null    float64
#  3   CharlesRvr         480 non-null    float64
#  4   NO2                480 non-null    float64
#  5   Roomsperhouse      480 non-null    object
#  6   oldhomeratio       480 non-null    object
#  7   distfromcenter     480 non-null    float64
#  8   roadaccessindex    480 non-null    float64
#  9   propertytax        480 non-null    object
#  10  pupilteacherratio  480 non-null    float64
#  11  mediahouseval      480 non-null    float64
# dtypes: float64(8), object(4)
# memory usage: 37.6+ KB

# %%
boston_data.isnull().sum().sort_values(ascending=False)
# Out:
# mediahouseval        0
# pupilteacherratio    0
# propertytax          0
# roadaccessindex      0
# distfromcenter       0
# oldhomeratio         0
# Roomsperhouse        0
# NO2                  0
# CharlesRvr           0
# IndusRatio           0
# ZoneRatio            0
# CrimeRate            0
# dtype: int64

# %%
boston_data['mediahouseval']  = boston_data['mediahouseval'].fillna(boston_data['mediahouseval'].mean())

# %%
boston_data.replace('NA', np.NaN)
# Out:
#     CrimeRate  ZoneRatio  IndusRatio  CharlesRvr    NO2 Roomsperhouse  \
# 0     0.02731        0.0        7.07         0.0  0.469        6.4210
# 1     0.02729        0.0        7.07         0.0  0.469        7.1850
# 2     0.03237        0.0        2.18         0.0  0.458        6.9980
# 3     0.06905        0.0        2.18         0.0  0.458        7.1470
# 4     0.02985        0.0        2.18         0.0  0.458        6.4300
# ..        ...        ...         ...         ...    ...           ...
# 475   0.06263        0.0       11.93         0.0  0.573        6.5930
# 476   0.04527        0.0       11.93         0.0  0.573        6.1200
# 477   0.06076        0.0       11.93         0.0  0.573        6.9760
# 478   0.10959        0.0       11.93         0.0  0.573        6.7940
# 479   0.04741        0.0       11.93         0.0  0.573        6.0300
#
#     oldhomeratio  distfromcenter  roadaccessindex propertytax  \
# 0          78.90          4.9671              2.0       242.0
# ...

# %%
features= boston_data.drop('mediahouseval', axis=1)
features
# Out:
#      CrimeRate  ZoneRatio  IndusRatio  CharlesRvr    NO2  Roomsperhouse  \
# 0      0.02731        0.0        7.07         0.0  0.469          6.421
# 1      0.02729        0.0        7.07         0.0  0.469          7.185
# 2      0.03237        0.0        2.18         0.0  0.458          6.998
# 3      0.06905        0.0        2.18         0.0  0.458          7.147
# 4      0.02985        0.0        2.18         0.0  0.458          6.430
# ..         ...        ...         ...         ...    ...            ...
# 475    0.06263        0.0       11.93         0.0  0.573          6.593
# 476    0.04527        0.0       11.93         0.0  0.573          6.120
# 477    0.06076        0.0       11.93         0.0  0.573          6.976
# 478    0.10959        0.0       11.93         0.0  0.573          6.794
# 479    0.04741        0.0       11.93         0.0  0.573          6.030
#
#      oldhomeratio  distfromcenter  roadaccessindex  propertytax  \
# ...

# %%
target = boston_data['mediahouseval']

# %%
obj_cols = [col for col in boston_data.columns if boston_data[col].dtypes == 'object']
obj_cols
# Out:
# ['CrimeRate', 'Roomsperhouse', 'oldhomeratio', 'propertytax']

# %%
for col in obj_cols:
    # boston_data[col].astype(float)
    boston_data[col] = pd.to_numeric(boston_data[col], errors='coerce',downcast='float')

# %%
boston_data[boston_data['CrimeRate']== np.NaN]
# Out:
# Empty DataFrame
# Columns: [CrimeRate, ZoneRatio, IndusRatio, CharlesRvr, NO2, Roomsperhouse, oldhomeratio, distfromcenter, roadaccessindex, propertytax, pupilteacherratio, mediahouseval]
# Index: []

# %%
boston_data.describe()
# Out:
#         CrimeRate   ZoneRatio  IndusRatio  CharlesRvr         NO2  \
# count  479.000000  480.000000  480.000000  480.000000  480.000000
# mean     3.285823   11.736083   10.803458    0.071690    0.561489
# std      8.529617   23.458471    6.845757    0.257262    0.307780
# min      0.009060    0.000000    0.000000    0.000000    0.385000
# 25%      0.079230    0.000000    5.130000    0.000000    0.448000
# 50%      0.224380    0.000000    8.560000    0.000000    0.524000
# 75%      2.322445   20.000000   18.100000    0.000000    0.624000
# max     88.976196   95.000000   27.740000    1.000000    6.816000
#
#        Roomsperhouse  oldhomeratio  distfromcenter  roadaccessindex  \
# count     437.000000    475.000000      480.000000       480.000000
# mean        6.424446     59.178402        5.227678        61.947917
# std         1.769212     32.211082        5.120003       168.291697
# min         3.561000      1.137000        1.129600         1.000000
# ...

# %%
boston_data.fillna(boston_data.mean(), inplace=True)

# %%
boston_data.isnull().sum().sort_values(ascending = False)
# Out:
# mediahouseval        0
# pupilteacherratio    0
# propertytax          0
# roadaccessindex      0
# distfromcenter       0
# oldhomeratio         0
# Roomsperhouse        0
# NO2                  0
# CharlesRvr           0
# IndusRatio           0
# ZoneRatio            0
# CrimeRate            0
# dtype: int64

# %%
from yellowbrick.target import FeatureCorrelation
feature_name = list(features.columns)

# %%
boston_data.dtypes =='object'
# Out:
# CrimeRate             True
# ZoneRatio            False
# IndusRatio           False
# CharlesRvr           False
# NO2                  False
# Roomsperhouse         True
# oldhomeratio          True
# distfromcenter       False
# roadaccessindex      False
# propertytax           True
# pupilteacherratio    False
# mediahouseval        False
# dtype: bool

# %%
 plt.figure(figsize=(10,8))
 boston_corr = boston_data.corr()
sns.heatmap(boston_corr, linewidth=1,annot=True, annot_kws={'size':10})
# boston_data.corr()

# %%
visualizer = FeatureCorrelation(labels=feature_name)
visualizer.fit(features, target)
visualizer.show()

# %%
from sklearn.feature_selection import SelectKBest, f_regression
univariate = SelectKBest(k=5, score_func=f_regression).fit(features, target)
mask = univariate.get_support()
features.columns[mask]
# Out:
# Index(['ZoneRatio', 'IndusRatio', 'Roomsperhouse', 'propertytax',
#        'pupilteacherratio'],
#       dtype='object')

# %%
univariate.scores_
# Out:
# array([4.16974166e+01, 6.39535661e+01, 1.08482301e+02, 1.71893539e+01,
#        7.90711429e+00, 4.37346092e+01, 2.73030482e+01, 6.62401691e-02,
#        4.06799297e+00, 6.01610025e+01, 3.17896414e+02])

# %%
feature_df = pd.DataFrame({'feature': features.columns, 'scores': univariate.scores_}).sort_values(by='scores', ascending=False)

# %%
uni_df = pd.DataFrame({'Univariate method': features.columns[mask]})
uni_df
# Out:
#    Univariate method
# 0          ZoneRatio
# 1         IndusRatio
# 2      Roomsperhouse
# 3        propertytax
# 4  pupilteacherratio

# %%
#wrapper methods using forward and backward 
from sklearn.feature_selection import RFE # RFE Recursive feature elimination
from sklearn.linear_model import LinearRegression
rfe = RFE(estimator=LinearRegression(), n_features_to_select=5)
rfe.fit(features, target)
# Out:
# RFE(estimator=LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#                                normalize=False),
#     n_features_to_select=5, step=1, verbose=0)

# %%
#get only those features from the rfe estimator
rfe_features = features.columns[rfe.support_]
rfe_features
# features.columns[rfe_features]
rfe_df = pd.DataFrame({'RFE Method': rfe_features})
rfe_df
# Out:
#           RFE Method
# 0         IndusRatio
# 1         CharlesRvr
# 2                NO2
# 3      Roomsperhouse
# 4  pupilteacherratio

# %%
# Out:
#      IndusRatio  CharlesRvr    NO2  Roomsperhouse  pupilteacherratio
# 0          7.07         0.0  0.469          6.421               9.14
# 1          7.07         0.0  0.469          7.185               4.03
# 2          2.18         0.0  0.458          6.998               2.94
# 3          2.18         0.0  0.458          7.147               5.33
# 4          2.18         0.0  0.458          6.430               5.21
# ..          ...         ...    ...            ...                ...
# 475       11.93         0.0  0.573          6.593               9.67
# 476       11.93         0.0  0.573          6.120               9.08
# 477       11.93         0.0  0.573          6.976               5.64
# 478       11.93         0.0  0.573          6.794               6.48
# 479       11.93         0.0  0.573          6.030               7.88
#
# [480 rows x 5 columns]
